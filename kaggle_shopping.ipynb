# %% [markdown]
# <a href="https://colab.research.google.com/github/Yeyeong99/Aiffel/blob/main/kaggle_shopping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import OrdinalEncoder
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv('/content/drive/MyDrive/shopping_trends.csv')

# %%
df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
enc = OrdinalEncoder()

# %%
gender = pd.DataFrame(df['Gender'])

# %%
gender
# Out:
#       Gender
# 0       Male
# 1       Male
# 2       Male
# 3       Male
# 4       Male
# ...      ...
# 3895  Female
# 3896  Female
# 3897  Female
# 3898  Female
# 3899  Female
#
# [3900 rows x 1 columns]

# %%
gender_trans = enc.fit_transform(gender)

# %%
df['Gender'] = gender_trans

# %%
df.head()
# Out:
#    Customer ID  Age  Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55     1.0         Blouse  Clothing                     53
# 1            2   19     1.0        Sweater  Clothing                     64
# 2            3   50     1.0          Jeans  Clothing                     73
# 3            4   21     1.0        Sandals  Footwear                     90
# 4            5   45     1.0         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
item = pd.DataFrame(df['Item Purchased'])

# %%
item_trans = enc.fit_transform(item)
len(item_trans)
# Out:
# 3900

# %%
df['Item Purchased'] = item_trans

# %%
df
# Out:
#       Customer ID  Age  Gender  Item Purchased     Category  \
# 0               1   55     1.0             2.0     Clothing
# 1               2   19     1.0            23.0     Clothing
# 2               3   50     1.0            11.0     Clothing
# 3               4   21     1.0            14.0     Footwear
# 4               5   45     1.0             2.0     Clothing
# ...           ...  ...     ...             ...          ...
# 3895         3896   40     0.0             9.0     Clothing
# 3896         3897   52     0.0             0.0  Accessories
# 3897         3898   46     0.0             1.0  Accessories
# 3898         3899   44     0.0            17.0     Footwear
# 3899         3900   52     0.0             7.0  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %% [markdown]
# ### 범주형에 해당하는 열들만 모아서 enc로 fit 한 뒤 다시 df에 반영하기
# - 각각의 colums를 리스트에 저장, for 문 활용해서 enc로 변환
# - 한꺼번에 pd.DataFrame하면 길이가 달라짐 (왜인지 모르겠음)

# %%
df_cols = ['Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season', 'Review Rating', 'Subscription Status', 'Payment Method', 'Shipping Type', 'Discount Applied', 'Promo Code Used', 'Preferred Payment Method', 'Frequency of Purchases']

# %%
df_category = pd.DataFrame(df[df_cols])
df_category
# Out:
#          Category  Purchase Amount (USD)       Location Size      Color  \
# 0        Clothing                     53       Kentucky    L       Gray
# 1        Clothing                     64          Maine    L     Maroon
# 2        Clothing                     73  Massachusetts    S     Maroon
# 3        Footwear                     90   Rhode Island    M     Maroon
# 4        Clothing                     49         Oregon    M  Turquoise
# ...           ...                    ...            ...  ...        ...
# 3895     Clothing                     28       Virginia    L  Turquoise
# 3896  Accessories                     49           Iowa    L      White
# 3897  Accessories                     33     New Jersey    L      Green
# 3898     Footwear                     77      Minnesota    S      Brown
# 3899  Accessories                     81     California    M      Beige
#
#       Season  Review Rating Subscription Status Payment Method  \
# ...

# %%
df_category_trans = enc.fit_transform(df_category)

# %%
df_category_trans # 왜 14개지?
# Out:
# array([ 1., 33., 16.,  0.,  7.,  3.,  6.,  1.,  2.,  1.,  1.,  1.,  5.,
#         3.])

# %%
category = pd.DataFrame(df['Category'])

# %%
cate_trans = enc.fit_transform(category)

# %%
len(cate_trans)
# Out:
# 3900

# %%
df['Category'] = enc.fit_transform(category)
df.head()
# Out:
#    Customer ID  Age  Gender  Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55     1.0             2.0       1.0                     53
# 1            2   19     1.0            23.0       1.0                     64
# 2            3   50     1.0            11.0       1.0                     73
# 3            4   21     1.0            14.0       2.0                     90
# 4            5   45     1.0             2.0       1.0                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
for i in df_cols:
  col = pd.DataFrame(df[i])
  col_trans = enc.fit_transform(col)
  df[i] = col_trans

df.head()
# Out:
#    Customer ID  Age  Gender  Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55     1.0             2.0       1.0                   33.0
# 1            2   19     1.0            23.0       1.0                   44.0
# 2            3   50     1.0            11.0       1.0                   53.0
# 3            4   21     1.0            14.0       2.0                   70.0
# 4            5   45     1.0             2.0       1.0                   29.0
#
#    Location  Size  Color  Season  Review Rating  Subscription Status  \
# 0      16.0   0.0    7.0     3.0            6.0                  1.0
# 1      18.0   0.0   12.0     3.0            6.0                  1.0
# 2      20.0   2.0   12.0     1.0            6.0                  1.0
# 3      38.0   1.0   12.0     1.0           10.0                  1.0
# 4      36.0   1.0   21.0     1.0            2.0                  1.0
#
#    Payment Method  Shipping Type  Discount Applied  Promo Code Used  \
# ...

# %%
for i in df_cols:
  print(len(set(df[i])))
# Out:
# 4
# 81
# 50
# 4
# 25
# 4
# 26
# 2
# 6
# 6
# 2
# 2
# 6
# 7

# %%
for i in range(len(df_cols)):
  df[df_cols[i]] = df_category_trans[i]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-8a535f1d5c54> in <cell line: 1>()
#       1 for i in range(len(df_cols)):
# ----> 2   df[df_cols[i]] = df_category_trans[i]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3978         else:
#    3979             # set column
# -> 3980             self._set_item(key, value)
#    3981
#    3982     def _setitem_slice(self, key: slice, value):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _set_item(self, key, value)
#    4172         ensure homogeneity.
#    4173         """
# -> 4174         value = self._sanitize_column(value)
#    4175
#    4176         if (
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _sanitize_column(self, value)
#    4913
#    4914         if is_list_like(value):
# ...

# %%
for i in df_cols:
  df[i] = df_cate_dict[i]

df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-094a41cf322c> in <cell line: 1>()
#       1 for i in df_cols:
# ----> 2   df[i] = df_cate_dict[i]
#       3
#       4 df.head()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3978         else:
#    3979             # set column
# -> 3980             self._set_item(key, value)
#    3981
#    3982     def _setitem_slice(self, key: slice, value):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _set_item(self, key, value)
#    4172         ensure homogeneity.
#    4173         """
# -> 4174         value = self._sanitize_column(value)
#    4175
#    4176         if (
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _sanitize_column(self, value)
#    4913
#    4914         if is_list_like(value):
# ...
